# %%
import numpy as np #Stored data as numpy arrays

import pickle #Pickle used to serialize dictionary of data and targets

from skimage.io import imread # Image pre-processing
from skimage.color import rgb2gray # Color to grayscale conversion
from skimage.transform import resize # Image resizing and standardisation

from sklearn import preprocessing # Used to scale data

import os # Directory navigation / manipulation

# %%
#Convert data


#Root directory containing Raw image files
root_dir = r'E:\\6006CEM\\6006CEM_2021s1_8696667_LS\\Model_1\\Dataset'


#Create arrays to store images and labels
Images = []
Targets = []

#Iteration counter
i = 0
tot = len(os.listdir(root_dir)) #Total files

#For each image
for f in os.listdir(root_dir):
    img = imread(root_dir + "\\" + f) #Read Image
    img = rgb2gray(img) #Convert to grayscale if colour
    img = resize(img, (512, 512),anti_aliasing=True) #Resize image
    img = img.flatten() #Flatten Matrix of image data into 1D array
    Images.append(img) #Append to array of images

    #If filename starts with Covid
    if f.startswith("COVID19"):
        Targets.append(1) #Append 1 to target array for positive
    else:
        Targets.append(0)#Append 0 to target array for negative
    
    
    #Update user with status of processing every 50 images
    i += 1
    if i % 50 == 0:
        print(str(i) + "/" + str(tot) + " Images processed")
# Out:
# 50/2159 Images processed
# 100/2159 Images processed
# 150/2159 Images processed
# 200/2159 Images processed
# 250/2159 Images processed
# 300/2159 Images processed
# 350/2159 Images processed
# 400/2159 Images processed
# 450/2159 Images processed
# 500/2159 Images processed
# 550/2159 Images processed
# 600/2159 Images processed
# 650/2159 Images processed
# 700/2159 Images processed
# 750/2159 Images processed
# 800/2159 Images processed
# 850/2159 Images processed
# 900/2159 Images processed
# 950/2159 Images processed
# 1000/2159 Images processed
# 1050/2159 Images processed
# 1100/2159 Images processed
# 1150/2159 Images processed
# 1200/2159 Images processed
# 1250/2159 Images processed
# 1300/2159 Images processed
# 1350/2159 Images processed
# 1400/2159 Images processed
# 1450/2159 Images processed
# 1500/2159 Images processed
# 1550/2159 Images processed
# 1600/2159 Images processed
# 1650/2159 Images processed
# 1700/2159 Images processed
# 1750/2159 Images processed
# 1800/2159 Images processed
# 1850/2159 Images processed
# 1900/2159 Images processed
# 1950/2159 Images processed
# 2000/2159 Images processed
# 2050/2159 Images processed
# 2100/2159 Images processed
# 2150/2159 Images processed

# %%
#Output directory for binary
save_dir = r'E:\\6006CEM\\6006CEM_2021s1_8696667_LS\\Model_1\\'

#Scale Data
Images = preprocessing.scale(Images)

#Create dictionary containing Image data and Target data
Xrays = {
    "data" : Images,
    "targets" : Targets
}

#Create / open file and dump dictionary using pickle
with open( save_dir + "Xray_data.p", "wb" ) as of:
    pickle.dump( Xrays, of)
